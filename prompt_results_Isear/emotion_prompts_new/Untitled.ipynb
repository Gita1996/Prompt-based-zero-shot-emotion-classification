# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC_nli_prompt-emotion-prediction_roberta.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()
entailment_probabilities=data['prob_emotion'].tolist()
max_entailment=list()

for m in entailment_probabilities:
    m = m.strip("[]")

# Step 2: Split the string by commas
    string_elements = m.split(",")

# Step 3: Convert each element to a float
    float_list = [float(element) for element in string_elements]
    
#    r=list(m)
#    print(m)
#    for d in float_list:
 #       arr = [float(i) for i in d[1:-1].split(",")]
 #       max_index=np.argmax(arr)
    max_entailment.append(max(float_list))

data['prob_max']= max_entailment       

data.to_csv('TEC_nli_prompt-emotion-prediction_roberta2.csv', index=False)

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.34      0.35      0.34      1555
#      disgust       0.14      0.50      0.22       761
#         fear       0.49      0.32      0.39      2816
#          joy       0.65      0.41      0.50      8240
#      sadness       0.39      0.49      0.44      3830
#     surprise       0.34      0.43      0.38      3849
#
#     accuracy                           0.42     21051
#    macro avg       0.39      0.42      0.38     21051
# weighted avg       0.49      0.42      0.43     21051

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('ISEAR-nli-prompt-emotion3-roberta2.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()

count1=0
count=0
for i in range(len(y_true)):
    if y_true[i]=='shame':
        count1+=1       
    if y_true[i]==y_pred[i]=='shame':
        count+=1
print(count1)
print(count)
# Out:
# 1071
# 278

# %%
import pandas as pd
data=pd.read_csv('ISEAR_dataset2.csv')
d=data['labels'].tolist()
r=sorted(list(set(d)))
print(r)
#['anger', 'disgust', 'fear', 'guilt', 'joy', 'sadness', 'shame']

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('ISEAR-nli-prompt-emotion3-roberta2.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.53      0.36      0.43      1079
#      disgust       0.69      0.38      0.49      1066
#         fear       0.84      0.40      0.55      1076
#        guilt       0.34      0.57      0.42      1049
#          joy       0.90      0.69      0.78      1092
#      sadness       0.35      0.85      0.49      1082
#        shame       0.66      0.26      0.37      1071
#
#     accuracy                           0.50      7515
#    macro avg       0.62      0.50      0.50      7515
# weighted avg       0.62      0.50      0.51      7515

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta2.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()
txt=data['text'].tolist()
prob_max = data['prob_max'].tolist()


count1=0
count=0
max_prob=0
max_index=0
for i in range(len(y_true)):
    if y_true[i]=='fear':
        count1+=1       
    if y_true[i]==y_pred[i]=='fear':
        count+=1
#        if prob_max[i]>max_prob:
#            max_prob=prob_max[i]
#            max_index=i
#print(txt[max_index])            
#and prob_max[i]>0.9
print(count1)
print(count)
#print(max_prob)
# Out:
# 1076
# 820

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta2.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()

anger_count=0
disgust_count=0
fear_count=0
guilt_count=0
joy_count=0
sadness_count=0
shame_count=0


for i in range(len(y_true)):
    if y_true[i]=='sadness':
        if y_pred[i]=='anger':
            anger_count+=1
        if y_pred[i]=='disgust':
            disgust_count+=1
        if y_pred[i]=='fear':
            fear_count+=1
        if y_pred[i]=='guilt':
            guilt_count+=1
        if y_pred[i]=='joy':
            joy_count+=1
        if y_pred[i]=='sadness':
            sadness_count+=1
        if y_pred[i]=='shame':
            shame_count+=1

print(anger_count)
print(disgust_count)
print(fear_count)
print(guilt_count)
print(joy_count)
print(sadness_count)
print(shame_count)

#disgust mistaken mostly with sadness count:217
#shame mistaken mostly with guilt count:308
# Out:
# 41
# 8
# 28
# 29
# 15
# 956
# 5
