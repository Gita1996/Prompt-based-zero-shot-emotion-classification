# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC_nli_prompt-emotion-prediction_roberta.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()
entailment_probabilities=data['prob_emotion'].tolist()
max_entailment=list()

for m in entailment_probabilities:
    m = m.strip("[]")

# Step 2: Split the string by commas
    string_elements = m.split(",")

# Step 3: Convert each element to a float
    float_list = [float(element) for element in string_elements]
    
#    r=list(m)
#    print(m)
#    for d in float_list:
 #       arr = [float(i) for i in d[1:-1].split(",")]
 #       max_index=np.argmax(arr)
    max_entailment.append(max(float_list))

data['prob_max']= max_entailment       

data.to_csv('TEC_nli_prompt-emotion-prediction_roberta2.csv', index=False)

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.34      0.35      0.34      1555
#      disgust       0.14      0.50      0.22       761
#         fear       0.49      0.32      0.39      2816
#          joy       0.65      0.41      0.50      8240
#      sadness       0.39      0.49      0.44      3830
#     surprise       0.34      0.43      0.38      3849
#
#     accuracy                           0.42     21051
#    macro avg       0.39      0.42      0.38     21051
# weighted avg       0.49      0.42      0.43     21051

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta2.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()

count=0
for i in range(len(y_true)):
    if y_true[i]==y_pred[i]:
        count+=1
print(count)
# Out:
# 4684

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
#data = pd.read_csv('ISEAR-nli-prompt-feels-emo3-Deberta.csv')
data = pd.read_csv('ISEAR-nli-prompt-feels-emo3-roberta.csv')
y_true = data['labels'].tolist()
y_pred = data['feels_emo'].tolist()

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.42      0.60      0.50      1079
#      disgust       0.79      0.31      0.45      1066
#         fear       0.41      0.68      0.51      1076
#        guilt       0.29      0.44      0.35      1049
#          joy       0.94      0.53      0.67      1092
#      sadness       0.66      0.62      0.64      1082
#        shame       0.38      0.19      0.25      1071
#
#     accuracy                           0.48      7515
#    macro avg       0.56      0.48      0.48      7515
# weighted avg       0.56      0.48      0.48      7515

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('ISEAR-nli-prompt-feels-emo3-bart.csv')
y_true = data['labels'].tolist()
y_pred = data['feels_emo'].tolist()

count1=0
count=0
for i in range(len(y_true)):
    if y_true[i]=='shame':
        count1+=1       
    if y_true[i]==y_pred[i]=='shame':
        count+=1
print(count1)
print(count)
# Out:
# 1071
# 226

# %%
import pandas as pd
data=pd.read_csv('ISEAR-nli-prompt-expr_emo3-Deberta.csv')
d=data['labels'].tolist()
r=sorted(list(set(d)))
print(r)
#['anger', 'disgust', 'fear', 'guilt', 'joy', 'sadness', 'shame']
