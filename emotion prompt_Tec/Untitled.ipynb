# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC_nli_prompt-emotion-prediction_roberta.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()
entailment_probabilities=data['prob_emotion'].tolist()
max_entailment=list()

for m in entailment_probabilities:
    m = m.strip("[]")

# Step 2: Split the string by commas
    string_elements = m.split(",")

# Step 3: Convert each element to a float
    float_list = [float(element) for element in string_elements]
    
#    r=list(m)
#    print(m)
#    for d in float_list:
 #       arr = [float(i) for i in d[1:-1].split(",")]
 #       max_index=np.argmax(arr)
    max_entailment.append(max(float_list))

data['prob_max']= max_entailment       

data.to_csv('TEC_nli_prompt-emotion-prediction_roberta2.csv', index=False)

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.34      0.35      0.34      1555
#      disgust       0.14      0.50      0.22       761
#         fear       0.49      0.32      0.39      2816
#          joy       0.65      0.41      0.50      8240
#      sadness       0.39      0.49      0.44      3830
#     surprise       0.34      0.43      0.38      3849
#
#     accuracy                           0.42     21051
#    macro avg       0.39      0.42      0.38     21051
# weighted avg       0.49      0.42      0.43     21051

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC_nli_prompt-emotion-prediction_file_deberta2.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()
txt=data['text'].tolist()
prob_max = data['prob_max'].tolist()


count1=0
count=0
max_prob=0
max_index=0
for i in range(len(y_true)):
    if y_true[i]=='fear':
        count1+=1       
    if y_true[i]==y_pred[i]=='fear' and prob_max[i]>0.9:
        count+=1
#        if prob_max[i]>max_prob:
#            max_prob=prob_max[i]
#            max_index=i
#print(txt[max_index])            
#and prob_max[i]>0.9
print(count1)
print(count)
#print(max_prob)

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta2.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()

count=0
for i in range(len(y_true)):
    if y_true[i]==y_pred[i]:
        count+=1
print(count)
# Out:
# 4684

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC_nli_prompt-emotion-prediction_file_deberta2.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.38      0.37      0.37      1555
#      disgust       0.18      0.45      0.26       761
#         fear       0.64      0.34      0.45      2816
#          joy       0.71      0.34      0.46      8240
#      sadness       0.51      0.40      0.45      3830
#     surprise       0.29      0.68      0.41      3849
#
#     accuracy                           0.42     21051
#    macro avg       0.45      0.43      0.40     21051
# weighted avg       0.54      0.42      0.43     21051

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('ISEAR-nli-prompt-expr_emo3-Deberta.csv')
y_true = data['labels'].tolist()
y_pred = data['expr_emo'].tolist()
txt=data['text'].tolist()
prob_max = data['prob_max'].tolist()


count1=0
count=0
max_prob=0
max_index=0
for i in range(len(y_true)):
    if y_true[i]=='disgust':
        count1+=1       
    if y_true[i]==y_pred[i]=='disgust':
        count+=1
        if prob_max[i]>max_prob:
            max_prob=prob_max[i]
            max_index=i
print(txt[max_index])            
#and prob_max[i]>0.9
print(count1)
print(count)
print(max_prob)
# index 5680
# Out:
# I was disgusted at the behavior of these boys I work with in the scouting program. They showed a lack of interest, unrest, and at times just plain rude behavior.
# 1066
# 495
# 0.9993113

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

data = pd.read_csv('TEC_nli_prompt-emotion-prediction_roberta2.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
#data = pd.read_csv('TEC_nli_prompt-emotion-prediction_file_deberta2.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()
txt=data['text'].tolist()
prob_max = data['prob_max'].tolist()


count1=0
count=0
max_prob=0
max_index=0
for i in range(len(y_true)):
    if y_true[i]=='fear':
        count1+=1       
    if y_true[i]==y_pred[i]=='fear':
        count+=1
#        if prob_max[i]>max_prob:
#            max_prob=prob_max[i]
#            max_index=i
#print(txt[max_index])            
#and prob_max[i]>0.9
print(count1)
print(count)
#print(max_prob)
# Out:
# 2816
# 896

# %%
import pandas as pd
data=pd.read_csv('ISEAR-nli-prompt-expr_emo3-Deberta.csv')
d=data['labels'].tolist()
r=sorted(list(set(d)))
print(r)
#['anger', 'disgust', 'fear', 'guilt', 'joy', 'sadness', 'shame']

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC_nli_prompt-emotion-prediction_roberta2.csv')
y_true = data['labels'].tolist()
y_pred = data['emotion'].tolist()

anger_count=0
disgust_count=0
fear_count=0
guilt_count=0
joy_count=0
sadness_count=0
shame_count=0
surprise_count=0


for i in range(len(y_true)):
    if y_true[i]=='anger':
        if y_pred[i]=='anger':
            anger_count+=1
        if y_pred[i]=='disgust':
            disgust_count+=1
        if y_pred[i]=='fear':
            fear_count+=1
        if y_pred[i]=='joy':
            joy_count+=1
        if y_pred[i]=='sadness':
            sadness_count+=1
        if y_pred[i]=='surprise':
            surprise_count+=1

print(anger_count)
print(disgust_count)
print(fear_count)
print(joy_count)
print(sadness_count)
print(surprise_count)
# Out:
# 547
# 382
# 81
# 80
# 287
# 178
