# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

data = pd.read_csv('TEC2_roberta_nli2.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
#data = pd.read_csv('TEC_nli_prompt-emotion-prediction_file_deberta2.csv')
y_true = data['labels'].tolist()
y_pred = data['emo_name'].tolist()
txt=data['text'].tolist()
prob_max = data['prob_max'].tolist()


count1=0
count=0
max_prob=0
max_index=0
for i in range(len(y_true)):
    if y_true[i]=='surprise':
        count1+=1       
    if y_true[i]==y_pred[i]=='fear':
        count+=1
#        if prob_max[i]>max_prob:
#            max_prob=prob_max[i]
#            max_index=i
#print(txt[max_index])            
#and prob_max[i]>0.9
print(count1)
print(count)
#print(max_prob)
# Out:
# 3849
# 716

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC2_roberta_nli2.csv')
y_true = data['labels'].tolist()
y_pred = data['emo_name'].tolist()

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.24      0.39      0.30      1555
#      disgust       0.13      0.48      0.20       761
#         fear       0.49      0.25      0.34      2816
#          joy       0.63      0.47      0.54      8240
#      sadness       0.42      0.54      0.47      3830
#     surprise       0.43      0.35      0.38      3849
#
#     accuracy                           0.43     21051
#    macro avg       0.39      0.41      0.37     21051
# weighted avg       0.49      0.43      0.44     21051

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
#TEC2_deberta_nli2.csv
#TEC-nli-prompt--emo name-bart.csv
data = pd.read_csv('Tec_emo_name_prompt_new_Deberta.csv')
y_true = data['labels'].tolist()
y_pred = data['emo_name'].tolist()

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.27      0.52      0.35      1555
#      disgust       0.19      0.38      0.26       761
#         fear       0.40      0.44      0.42      2816
#          joy       0.66      0.49      0.56      8240
#      sadness       0.48      0.51      0.49      3830
#     surprise       0.44      0.37      0.40      3849
#
#     accuracy                           0.46     21051
#    macro avg       0.41      0.45      0.41     21051
# weighted avg       0.51      0.46      0.47     21051

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC2_roberta_nli2.csv')
y_true = data['labels'].tolist()
y_pred = data['emo_name'].tolist()

anger_count=0
disgust_count=0
fear_count=0
guilt_count=0
joy_count=0
sadness_count=0
surprise_count=0


for i in range(len(y_true)):
    if y_true[i]=='anger':
        if y_pred[i]=='anger':
            anger_count+=1
        if y_pred[i]=='disgust':
            disgust_count+=1
        if y_pred[i]=='fear':
            fear_count+=1
        if y_pred[i]=='joy':
            joy_count+=1
        if y_pred[i]=='sadness':
            sadness_count+=1
        if y_pred[i]=='surprise':
            surprise_count+=1

print(anger_count)
print(disgust_count)
print(fear_count)
print(joy_count)
print(sadness_count)
print(surprise_count)
# Out:
# 604
# 354
# 72
# 121
# 323
# 81
