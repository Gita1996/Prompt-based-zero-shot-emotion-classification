# %%
# Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#data=pd.read_csv('Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv')

#TEC_nli_syn_avg_emotion_prompt_syn_prob.csv
data=pd.read_csv('TEC_nli_syn_avg_emotion_prompt_syn_prob.csv')

d= data['probs_synonyms']
e=data['emotion']
d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()
surprise=list()

for i in range(len(label_list)):
    if label_list[i]=='anger' and e[i]=='anger':
        anger.append(d[i])
    if label_list[i]=='disgust' and e[i]=='disgust':
        disgust.append(d[i])
    if label_list[i]=='fear' and e[i]=='fear':
        fear.append(d[i])
    if label_list[i]=='joy' and e[i]=='joy':
        joy.append(d[i])
    if label_list[i]=='sadness' and e[i]=='sadness':
        sadness.append(d[i])
    if label_list[i]=='surprise' and e[i]=='surprise':
        surprise.append(d[i])
                    
#m=np.sum(anger, axis=0)/len(anger)
#m=np.average(anger, axis=0)
#an=[sum(x)/len(x) for x in zip(*anger)]

avg_syn_anger=list()
#anger 6


for i in range(6):
    s=0
    for m in surprise:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        
#        print(float_list)
#        print("#")
        if float_list[i]: 
            s+=float_list[i]
    avg_syn_anger.append(s/len(surprise))
        
        
print(avg_syn_anger)

#anger  [0.8924125560279935, 0.8295309145539068, 0.8084144839888904, 0.8173117821413325, 0.8152186945290305, 0.9221459856571164]
#'irritation'
#disgust [0.9336106904624206, 0.8697014231023923, 0.7764004435785606, 0.7404554224256777, 0.9477792362208074, 0.9192934726347338]
#'repugnance'
#fear [0.9134123391784921, 0.6636428358063406, 0.8495520940522165, 0.7555416487428311, 0.804286938918361, 0.9045788941680101]
#'fear'
#joy [0.8180745185850745, 0.5857311474274043, 0.8650664496218226, 0.7599318308784859, 0.8613397440817651, 0.6548269451292331]
#'pleasure'
#sadness [0.9071235619696354, 0.8658870406419412, 0.8027665491656661, 0.8590954278490149, 0.669062918579733, 0.6355105552252284]
#'sadness'
#surprise [0.887585661819312, 0.8098607066804114, 0.7493400170305884, 0.7036240059525617, 0.7863989145164938, 0.6883139446528121]
#'surprise'
# Out:
# [0.887585661819312, 0.8098607066804114, 0.7493400170305884, 0.7036240059525617, 0.7863989145164938, 0.6883139446528121]

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#data=pd.read_csv('Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv')

#TEC_nli_syn_avg_emotion_prompt_syn_prob.csv
data=pd.read_csv('TEC_nli_syn_avg_emotion_prompt_syn_prob.csv')

d= data['probs_synonyms']
e=data['emotion']
d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()
surprise=list()

for i in range(len(label_list)):
    if label_list[i]=='anger' and e[i]!='anger':
        anger.append(d[i])
    if label_list[i]=='disgust' and e[i]!='disgust':
        disgust.append(d[i])
    if label_list[i]=='fear' and e[i]!='fear':
        fear.append(d[i])
    if label_list[i]=='joy' and e[i]!='joy':
        joy.append(d[i])
    if label_list[i]=='sadness' and e[i]!='sadness':
        sadness.append(d[i])
    if label_list[i]=='surprise' and e[i]!='surprise':
        surprise.append(d[i])
                    
#m=np.sum(anger, axis=0)/len(anger)
#m=np.average(anger, axis=0)
#an=[sum(x)/len(x) for x in zip(*anger)]

avg_syn_anger=list()
#anger 6


for i in range(6):
    s=0
    for m in surprise:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        
#        print(float_list)
#        print("#")
        if float_list[i]: 
            s+=float_list[i]
    avg_syn_anger.append(s/len(surprise))
        
        
print(avg_syn_anger)

#anger [0.4591041476542087, 0.5949160967839401, 0.3310523466742135, 0.434399134684462, 0.34979678266396474, 0.6554215740603673]
#'irritation'
#disgust [0.6039033354053015, 0.48075992055161015, 0.5401850214437863, 0.2849469902625236, 0.691200844841308, 0.5560794432551062]
#'repugnance'
#fear [0.6039033354053015, 0.48075992055161015, 0.5401850214437863, 0.2849469902625236, 0.691200844841308, 0.5560794432551062]
#'dread'
#joy [0.18937986041572183, 0.21118616773971746, 0.27315685216074553, 0.30349978136854305, 0.24532498709866588, 0.16728522700856255]
#'the awesome'
#sadness [0.4531452879706794, 0.5398320028445911, 0.38664886504416135, 0.3952306403959563, 0.3066138698781982, 0.2949149997175779]
#'unhappiness'
#surprise [0.728261338792212, 0.5555790136671648, 0.5303791279549153, 0.7916048053501649, 0.44708467574413396, 0.38625643706489327]
#'impression'
# Out:
# [0.728261338792212, 0.5555790136671648, 0.5303791279549153, 0.7916048053501649, 0.44708467574413396, 0.38625643706489327]

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#data=pd.read_csv('Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv')

#TEC_nli_syn_avg_emotion_prompt_syn_prob.csv
data=pd.read_csv('TEC_nli_syn_avg_syn_probs_predicted_column.csv')

d= data['probs_synonyms']
e=data['emotion']
d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()
surprise=list()

for i in range(len(label_list)):
    if label_list[i]!='anger' and e[i]=='anger':
        anger.append(d[i])
    if label_list[i]!='disgust' and e[i]=='disgust':
        disgust.append(d[i])
    if label_list[i]!='fear' and e[i]=='fear':
        fear.append(d[i])
    if label_list[i]!='joy' and e[i]=='joy':
        joy.append(d[i])
    if label_list[i]!='sadness' and e[i]=='sadness':
        sadness.append(d[i])
    if label_list[i]!='surprise' and e[i]=='surprise':
        surprise.append(d[i])
                    
#m=np.sum(anger, axis=0)/len(anger)
#m=np.average(anger, axis=0)
#an=[sum(x)/len(x) for x in zip(*anger)]

avg_syn_anger=list()
#anger 6


for i in range(6):
    s=0
    for m in surprise:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        
#        print(float_list)
#        print("#")
        if float_list[i]: 
            s+=float_list[i]
    avg_syn_anger.append(s/len(surprise))
        
        
print(avg_syn_anger)
# Out:
# [0.6280303804246838, 0.5462186668952389, 0.5067577001513219, 0.7751442861930908, 0.5753830952448066, 0.424041106807004]

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#data=pd.read_csv('Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv')

#TEC_nli_syn_avg_emotion_prompt_syn_prob.csv
data=pd.read_csv('TEC_nli_syn_avg_emotion_prompt_syn_prob.csv')
#data=pd.read_csv('TEC_nli_syn_avg_emotion_prompt.csv')

d= data['probs_synonyms']
e=data['emotion']
d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()

anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()
surprise=list()

for i in range(len(label_list)):
    if label_list[i]=='anger':
        anger.append(d[i])
    if label_list[i]=='disgust':
        disgust.append(d[i])
    if label_list[i]=='fear':
        fear.append(d[i])
    if label_list[i]=='joy':
        joy.append(d[i])
    if label_list[i]=='sadness':
        sadness.append(d[i])
    if label_list[i]=='surprise':
        surprise.append(d[i])
                    
#m=np.sum(anger, axis=0)/len(anger)
#m=np.average(anger, axis=0)
#an=[sum(x)/len(x) for x in zip(*anger)]

avg_syn_anger=list()
#anger 6


for i in range(6):
    s=0
    for m in joy:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        
#        print(float_list)
#        print("#")
        if float_list[i]: 
            s+=float_list[i]
    avg_syn_anger.append(s/len(joy))
        
        
print(avg_syn_anger)

print(len(anger))
print(len(disgust))
print(len(fear))
print(len(joy))
print(len(sadness))
print(len(surprise))

#anger [0.6820280876535836, 0.715618253836013, 0.5766405845209926, 0.6313959951124339, 0.5892421392504937, 0.7926431362966369]
#irritstion
#disgust [0.7187160148929973, 0.6161994713741559, 0.6224413773777091, 0.4435668779408887, 0.7805481164780588, 0.682560018531849]
#repugnance
#fear [0.545392175803551, 0.37073661958542786, 0.5373176667042737, 0.38278963765889207, 0.4576971486041078, 0.596588851994449]
#scare
#joy [0.44574078898963265, 0.36391324683566745, 0.5145180472419614, 0.4896177044696848, 0.4965154705286675, 0.3660886460480593]
#happiness
#sadness [0.5806859205615088, 0.6314338881370058, 0.5035529454918739, 0.5255487895603143, 0.40844028669356414, 0.3906018972962286]
#unhappiness
#surprise [0.8209418166455965, 0.7034970990547095, 0.6577507649100808, 0.7404255354485714, 0.6444670037803287, 0.561966169330248]
#surprise
# Out:
# [0.44574078898963265, 0.36391324683566745, 0.5145180472419614, 0.4896177044696848, 0.4965154705286675, 0.3660886460480593]
# 1555
# 761
# 2816
# 8240
# 3830
# 3849

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#data=pd.read_csv('Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv')

#TEC_nli_syn_avg_emotion_prompt_syn_prob.csv
data1=pd.read_csv('TEC_nli_syn_avg_emotion_prompt_syn_prob.csv')
data=pd.read_csv('TEC_nli_syn_avg_emotion_prompt.csv')

d= data1['probs_synonyms']
e=data['emotion']
#d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()

anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()
surprise=list()

for i in range(len(label_list)):
    if e[i]=='anger':
        anger.append(d[i])
    if e[i]=='disgust':
        disgust.append(d[i])
    if e[i]=='fear':
        fear.append(d[i])
    if e[i]=='joy':
        joy.append(d[i])
    if e[i]=='sadness':
        sadness.append(d[i])
    if e[i]=='surprise':
        surprise.append(d[i])
                    
#m=np.sum(anger, axis=0)/len(anger)
#m=np.average(anger, axis=0)
#an=[sum(x)/len(x) for x in zip(*anger)]

avg_syn_anger=list()
var_anger=list()

#anger 6



for i in range(6):
    s=0
    set_syn=list()
    for m in fear:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        
#        print(float_list)
#        print("#")
        if float_list[i]: 
            s+=float_list[i]
            set_syn.append(float_list[i])
            
    avg_syn_anger.append(s/len(fear))
    var_anger.append(statistics.variance(set_syn))
        
        
print(avg_syn_anger)
print(var_anger)


#anger [0.5516866450154839, 0.5578464921643649, 0.5061740405677572, 0.5177701661343876, 0.4955558817841135, 0.5261278856323381]
#disgust [0.5516866450154839, 0.5578464921643649, 0.5061740405677572, 0.5177701661343876, 0.4955558817841135, 0.5261278856323381]
#fear [0.5516866450154839, 0.5578464921643649, 0.5061740405677572, 0.5177701661343876, 0.4955558817841135, 0.5261278856323381]
#joy [0.7148653522246523, 0.5090623853568546, 0.7321917253915416, 0.6836386677267074, 0.6486428847692063, 0.5090671809590551]
#sadness [0.6372257315523415, 0.6129233085841728, 0.5651109801780931, 0.6383851519744658, 0.504729317940004, 0.4871085905123602]
#surprise  [0.5008239048770274, 0.4770498141452384, 0.48657165272456265, 0.4503115886410679, 0.4737727936792806, 0.40802875696040897]
# Out:
# [0.6103145625778753, 0.5155710951576469, 0.5465053092948516, 0.5602382592386702, 0.5217706094330936, 0.6034851890566472]
# [0.172749980185299, 0.14061513217538207, 0.15977848574352205, 0.13245262252247533, 0.15785085465300225, 0.15481718226607885]

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#data=pd.read_csv('Isear_nli_syn_avg_emotion_prompt2.csv')
data2=pd.read_csv('TEC_nli_syn_avg_emotion_prompt.csv')


d= data2['prob_emotion']
e=data2['emotion']
d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()
unique_labels = sorted(list(set(label_list)))

prob_max_l=list()
###############

for m in d2:
    m = m.strip("[]")    
    string_elements = m.split(",")
    float_list = [float(element) for element in string_elements]
    prob_max=max(float_list)
#    print(prob_max)
#    print("//")
    prob_max_l.append(prob_max)

#print(len(prob_max_l))
data2['prob_max']=prob_max_l       
        
data2.to_csv('TEC_nli_syn_avg_emotion_prompt2.csv', index=False)
# Out:
# 0.8475495278835297
# //
# 0.7115395069122314
# //
# 0.9245569507280985
# //
# 0.7815960645675659
# //
# 0.9128030439217886
# //
# 0.5748263647158941
# //
# 0.8441286484400431
# //
# 0.7265647798776627
# //
# 0.6760367353757223
# //
# 0.8820123771826426
# //
# 0.6586340715487798
# //
# 0.9412832955519358
# //
# 0.663398360212644
# //
# 0.976220041513443
# //
# 0.43641336262226105
# //
# 0.9377264678478241
# //
# 0.7437878996133804
# //
# 0.8244637002547582
# //
# 0.6948761108020941
# //
# 0.900518407424291
# //
# 0.48894032028814155
# //
# 0.6910713501274586
# //
# 0.890192578236262
# //
# 0.9309265812238058
# //
# 0.6807190726200739
# //
# 0.5704128742218018
# //
# 0.40192699432373047
# //
# 0.7085418502489725
# //
# 0.9853450258572897
# //
# 0.7390142232179642
# //
# 0.9292400479316711
# //
# 0.8178024490674337
# //
# 0.6406628241141638
# //
# 0.9143227636814117
# //
# 0.9102497498194376
# //
# 0.7331806297103564
# //
# 0.16600163529316583
# //
# 0.6824466983477274
# //
# ...

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
data=pd.read_csv('Isear_nli_syn_avg_emotion_prompt2.csv')

d1= data['prob_max']
e1=data['emotion']
d11=d1.tolist()
#print(d[0])

label_list = data['labels'].tolist()
unique_labels = sorted(list(set(label_list)))
#print(unique_labels)
#'anger', 'disgust', 'fear', 'guilt', 'joy', 'sadness', 'shame'
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()
surprise=list()
#################
data2=pd.read_csv('TEC_nli_syn_avg_emotion_prompt2.csv')

d2= data2['prob_max']
e2=data2['emotion']
d22=d2.tolist()
label_list2 = data2['labels'].tolist()
#print(d[0])


for i in range(len(label_list)):
    if label_list[i]=='anger' and e1[i]=='anger':
        anger.append(d1[i])
    if label_list[i]=='disgust' and e1[i]=='disgust':
        disgust.append(d1[i])
    if label_list[i]=='fear' and e1[i]=='fear':
        fear.append(d1[i])
    if label_list[i]=='guilt' and e1[i]=='guilt':
        guilt.append(d1[i])
    if label_list[i]=='joy' and e1[i]=='joy':
        joy.append(d1[i])
    if label_list[i]=='sadness' and e1[i]=='sadness':
        sadness.append(d1[i])
    if label_list[i]=='shame' and e1[i]=='shame':
        shame.append(d1[i])
        
for i in range(len(label_list2)):
    if label_list2[i]=='anger' and e2[i]=='anger':
        anger.append(d2[i])
    if label_list2[i]=='disgust' and e2[i]=='disgust':
        disgust.append(d2[i])
    if label_list2[i]=='fear' and e2[i]=='fear':
        fear.append(d2[i])
    if label_list2[i]=='joy' and e2[i]=='joy':
        joy.append(d2[i])
    if label_list2[i]=='sadness' and e2[i]=='sadness':
        sadness.append(d2[i])
    if label_list2[i]=='surprise' and e2[i]=='surprise':
        surprise.append(d2[i])

# %%
anger.sort()
#print(anger)
disgust.sort()
fear.sort()
guilt.sort()
joy.sort()
sadness.sort()
shame.sort()
surprise.sort()
##
anger_index=int(len(anger)/4)
disgust_index=int(len(disgust)/4)
fear_index=int(len(fear)/4)
guilt_index=int(len(guilt)/4)
joy_index=int(len(joy)/4)
sadness_index=int(len(sadness)/4)
shame_index=int(len(shame)/4)
surprise_index=int(len(surprise)/4)
print('anger', anger[anger_index])
print('disgust', disgust[disgust_index])
print('fear', fear[fear_index])
print('guilt', guilt[guilt_index])
print('joy',joy[joy_index])
print('sadness', sadness[sadness_index])
print('shame', shame[shame_index])
print('surprise', surprise[surprise_index])
# Out:
# anger 0.8177475978930792
# disgust 0.8545556763807932
# fear 0.7896624654531479
# guilt 0.8271377484003702
# joy 0.6956736793120702
# sadness 0.770032487809658
# shame 0.8917814989884695
# surprise 0.6769277254740397

# %%
anger.sort()
#print(anger)
disgust.sort()
fear.sort()
guilt.sort()
joy.sort()
sadness.sort()
shame.sort()
surprise.sort()
##
anger_index=int(len(anger)/2)
disgust_index=int(len(disgust)/2)
fear_index=int(len(fear)/2)
guilt_index=int(len(guilt)/2)
joy_index=int(len(joy)/2)
sadness_index=int(len(sadness)/2)
shame_index=int(len(shame)/2)
surprise_index=int(len(surprise)/2)
print('anger', anger[anger_index])
print('disgust', disgust[disgust_index])
print('fear', fear[fear_index])
print('guilt', guilt[guilt_index])
print('joy',joy[joy_index])
print('sadness', sadness[sadness_index])
print('shame', shame[shame_index])
print('surprise', surprise[surprise_index])
# Out:
# anger 0.9185779988765717
# disgust 0.9204711417357128
# fear 0.91556586821874
# guilt 0.8981374800205231
# joy 0.825237900018692
# sadness 0.8717359403769175
# shame 0.9512792627016704
# surprise 0.8216500480969747

# %%
anger.sort()
#print(anger)
disgust.sort()
fear.sort()
guilt.sort()
joy.sort()
sadness.sort()
shame.sort()
surprise.sort()
##
anger_index=int(3*len(anger)/4)
disgust_index=int(3*len(disgust)/4)
fear_index=int(3*len(fear)/4)
guilt_index=int(3*len(guilt)/4)
joy_index=int(len(joy)/2)
sadness_index=int(len(sadness)/2)
shame_index=int(len(shame)/2)
surprise_index=int(len(surprise)/2)
print('anger', anger[anger_index])
print('disgust', disgust[disgust_index])
print('fear', fear[fear_index])
print('guilt', guilt[guilt_index])
print('joy',joy[joy_index])
print('sadness', sadness[sadness_index])
print('shame', shame[shame_index])
print('surprise', surprise[surprise_index])
# Out:
# anger 0.968538741270701
# disgust 0.9685034155845642
# fear 0.9696524937947592
# guilt 0.9361487130324044
# joy 0.825237900018692
# sadness 0.8717359403769175
# shame 0.9512792627016704
# surprise 0.8216500480969747

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
data=pd.read_csv('Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv')


#d1= data['prob_max']
e1=data['emotion']
prob_syn1=data['probs_synonyms']
d11=d1.tolist()
#print(d[0])

label_list = data['labels'].tolist()
unique_labels = sorted(list(set(label_list)))
print(unique_labels)
#'anger', 'disgust', 'fear', 'guilt', 'joy', 'sadness', 'shame'
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()
surprise=list()
#################
data2=pd.read_csv('TEC_nli_syn_avg_emotion_prompt_syn_prob.csv')

#d2= data2['prob_max']
e2=data2['emotion']
prob_syn2=data2['probs_synonyms']
d22=d2.tolist()
label_list2 = data2['labels'].tolist()
unique_labels = sorted(list(set(label_list2)))
print(unique_labels)
#print(d[0])


for i in range(len(label_list)):
    if label_list[i]=='anger' and e1[i]=='anger':
        anger.append(prob_syn1[i])
    if label_list[i]=='disgust' and e1[i]=='disgust':
        disgust.append(prob_syn1[i])
    if label_list[i]=='fear' and e1[i]=='fear':
        fear.append(prob_syn1[i])
    if label_list[i]=='guilt' and e1[i]=='guilt':
        guilt.append(prob_syn1[i])
    if label_list[i]=='joy' and e1[i]=='joy':
        joy.append(prob_syn1[i])
    if label_list[i]=='sadness' and e1[i]=='sadness':
        sadness.append(prob_syn1[i])
    if label_list[i]=='shame' and e1[i]=='shame':
        shame.append(prob_syn1[i])
        
for i in range(len(label_list2)):
    if label_list2[i]=='anger' and e2[i]=='anger':
        anger.append(prob_syn2[i])
    if label_list2[i]=='disgust' and e2[i]=='disgust':
        disgust.append(prob_syn2[i])
    if label_list2[i]=='fear' and e2[i]=='fear':
        fear.append(prob_syn2[i])
    if label_list2[i]=='joy' and e2[i]=='joy':
        joy.append(prob_syn2[i])
    if label_list2[i]=='sadness' and e2[i]=='sadness':
        sadness.append(prob_syn2[i])
    if label_list2[i]=='surprise' and e2[i]=='surprise':
        surprise.append(prob_syn2[i])
# Out:
# ['anger', 'disgust', 'fear', 'guilt', 'joy', 'sadness', 'shame']
# ['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise']

# %%
avg_syn_anger=list()
#anger 6


for i in range(6):
    s=0
    for m in shame:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        
#        print(float_list)
#        print("#")
        if float_list[i]: 
            s+=float_list[i]
    avg_syn_anger.append(s/len(shame))

print(avg_syn_anger)

#anger  [0.8921091897140135, 0.8124934933646716, 0.7995561008659986, 0.8283847495535993, 0.8086769316747514, 0.9269463592394889]
#irritation
#disgust [0.9288452069522865, 0.8594047691467979, 0.749414100602628, 0.7804638047360841, 0.9539725888862249, 0.9155881141098814]
#repugnance
#fear [0.9345078526910603, 0.7362288086260508, 0.8853394181325508, 0.818768292507301, 0.8486744308121573, 0.9328308129179179]
#fear
#guilt [0.9014457353075181, 0.9435913241106617, 0.9016841007596698, 0.7796272958359443, 0.830663724403736, 0.8517697268835277]
# culpability   
#joy [0.8351537854320693, 0.6229279161588797, 0.8765984844427361, 0.7682337258513591, 0.8761357701773542, 0.6698246877109157]  
# pleasure
#sadness [0.9253657061034093, 0.896576450348945, 0.8440067231409132, 0.88907809067714, 0.7026208173182233, 0.6808605489415476]
# sadness
#shame [0.9345220033222342, 0.9548121391381421, 0.9505319093810247, 0.9215136187710289, 0.9284411342499218, 0.9099911152643759]
# humiliation
#surprise [0.9253657061034093, 0.896576450348945, 0.8440067231409132, 0.88907809067714, 0.7026208173182233, 0.6808605489415476]
# surprise
# Out:
# [0.9345220033222342, 0.9548121391381421, 0.9505319093810247, 0.9215136187710289, 0.9284411342499218, 0.9099911152643759]

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
data=pd.read_csv('Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv')


#d1= data['prob_max']
e1=data['emotion']
prob_syn1=data['probs_synonyms']
d11=d1.tolist()
#print(d[0])

label_list = data['labels'].tolist()
unique_labels = sorted(list(set(label_list)))
#print(unique_labels)
#'anger', 'disgust', 'fear', 'guilt', 'joy', 'sadness', 'shame'
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()
surprise=list()
#################
data2=pd.read_csv('TEC_nli_syn_avg_emotion_prompt_syn_prob.csv')

#d2= data2['prob_max']
e2=data2['emotion']
prob_syn2=data2['probs_synonyms']
d22=d2.tolist()
label_list2 = data2['labels'].tolist()
#print(d[0])


for i in range(len(label_list)):
    if label_list[i]=='anger' and e1[i]!='anger':
        anger.append(prob_syn1[i])
    if label_list[i]=='disgust' and e1[i]!='disgust':
        disgust.append(prob_syn1[i])
    if label_list[i]=='fear' and e1[i]!='fear':
        fear.append(prob_syn1[i])
    if label_list[i]=='guilt' and e1[i]!='guilt':
        guilt.append(prob_syn1[i])
    if label_list[i]=='joy' and e1[i]!='joy':
        joy.append(prob_syn1[i])
    if label_list[i]=='sadness' and e1[i]!='sadness':
        sadness.append(prob_syn1[i])
    if label_list[i]=='shame' and e1[i]!='shame':
        shame.append(prob_syn1[i])
        
for i in range(len(label_list2)):
    if label_list2[i]=='anger' and e2[i]!='anger':
        anger.append(prob_syn2[i])
    if label_list2[i]=='disgust' and e2[i]!='disgust':
        disgust.append(prob_syn2[i])
    if label_list2[i]=='fear' and e2[i]!='fear':
        fear.append(prob_syn2[i])
    if label_list2[i]=='joy' and e2[i]!='joy':
        joy.append(prob_syn2[i])
    if label_list2[i]=='sadness' and e2[i]!='sadness':
        sadness.append(prob_syn2[i])
    if label_list2[i]=='surprise' and e2[i]!='surprise':
        surprise.append(prob_syn2[i])

# %%
avg_syn_anger=list()
#anger 6


for i in range(6):
    s=0
    for m in shame:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        
#        print(float_list)
#        print("#")
        if float_list[i]: 
            s+=float_list[i]
    avg_syn_anger.append(s/len(shame))

print(avg_syn_anger)


#anger [0.6112670509165976, 0.7108797357746504, 0.4510310259571854, 0.5784859955378632, 0.47870804502914477, 0.764651241498816]
#irritation
#disgust [0.686788427950226, 0.5587645764645173, 0.6196188970650826, 0.44815086390793707, 0.7846087037621817, 0.6454007207127139]
#repugnance
# shame [0.6524708065986419, 0.6917790640871282, 0.7174428274332632, 0.5963307672724681, 0.692394197096894, 0.663599719538481][0.20996879605239224, 0.22791274045207308, 0.29156087718122264, 0.31873062910859146, 0.2672687724625349, 0.18300029015810873]
#embarrassment
#fear [0.42275069029810625, 0.2859747319307381, 0.43953740238428685, 0.26137319766460876, 0.34547663815066093, 0.49949256973860084] 
#scare
#joy [0.20996879605239224, 0.22791274045207308, 0.29156087718122264, 0.31873062910859146, 0.2672687724625349, 0.18300029015810873]
#the awesome
#shame [0.6524708065986419, 0.6917790640871282, 0.7174428274332632, 0.5963307672724681, 0.692394197096894, 0.663599719538481]
#sadness [0.42275069029810625, 0.2859747319307381, 0.43953740238428685, 0.26137319766460876, 0.34547663815066093, 0.49949256973860084]
#depression
#guilt [0.7839212294642788, 0.8698427176925244, 0.7991742772062788, 0.6701088558697889, 0.7780364104001237, 0.7129228888982792]
#culpability
# Out:
# [0.6524708065986419, 0.6917790640871282, 0.7174428274332632, 0.5963307672724681, 0.692394197096894, 0.663599719538481]

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#TEC_nli_syn_avg_emotion_prompt_syn_prob.csv
data=pd.read_csv('TEC_nli_syn_avg_emotion_prompt_syn_prob.csv')

d= data['probs_synonyms']
e=data['emotion']
d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()


for i in range(len(label_list)):
    if label_list[i]=='anger':
        anger.append(d[i])
    if label_list[i]=='disgust':
        disgust.append(d[i])
    if label_list[i]=='fear':
        fear.append(d[i])
    if label_list[i]=='guilt':
        guilt.append(d[i])
    if label_list[i]=='joy':
        joy.append(d[i])
    if label_list[i]=='sadness':
        sadness.append(d[i])
    if label_list[i]=='shame':
        shame.append(d[i])
                    
#m=np.sum(anger, axis=0)/len(anger)
#m=np.average(anger, axis=0)
#an=[sum(x)/len(x) for x in zip(*anger)]

avg_syn_anger=list()
#anger 6
anger2=0
annoyance2=0 
rage2=0
outrage2=0
fury2=0
irritation2=0

#0:'anger', 1:'annoyance', 2:'rage', 3:'outrage', 4:'fury', 5:'irritation'

for i in range(6):
    s=0
    for m in anger:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        max_index=np.argmax(float_list)
#        print(float_list)
#        print("#")
        if max_index==0:
            anger2+=1
        if max_index==1:
            annoyance2+=1
        if max_index==2:
            rage2+=1
        if max_index==3:
            outrage2+=1
        if max_index==4:
            fury2+=1
        if max_index==5:
            irritation2+=1
        
        
disgust2=0 
loathing2=0
itterness2=0
ugliness2=0
repugnance2=0
revulsion2=0

for i in range(6):
    s=0
    for m in disgust:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        max_index=np.argmax(float_list)
#        print(float_list)
#        print("#")
        if max_index==0:
            disgust2+=1
        if max_index==1:
            loathing2+=1
        if max_index==2:
            itterness2+=1
        if max_index==3:
            ugliness2+=1
        if max_index==4:
            repugnance2+=1
        if max_index==5:
            revulsion2+=1
        
        
print(disgust2)
print(loathing2)
print(itterness2)
print(ugliness2)
print(repugnance2)
print(revulsion2)
# Out:
# 780
# 186
# 486
# 150
# 2508
# 456

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
data=pd.read_csv('TEC_nli_syn_avg_emotion_prompt2.csv')
data2=pd.read_csv('TEC_nli_syn_avg_two_syn_new.csv')
#Isear_nli_syn_avg_emo_s_prompt2.csv
#Isear_nli_syn_avg_expr_s.csv

prob_emotion=data['prob_emotion']
prob_expr_s=data2['prob_emotion']

prob_emotion2=list()
prob_expr_s2=list()

for m in prob_emotion:
    m = m.strip("[]")    
    string_elements = m.split(",")
    float_list = [float(element) for element in string_elements]
    prob_emotion2.append(float_list)

for m in prob_expr_s:
    m = m.strip("[]")    
    string_elements = m.split(",")
    float_list = [float(element) for element in string_elements]
    prob_expr_s2.append(float_list)


predict=list()
prob_emo=list()

for i in range(len(prob_emotion2)):
    combined_predict=list()
    for j in range(len(prob_emotion2[0])):
        a=(prob_emotion2[i][j]+prob_expr_s2[i][j])/2
        combined_predict.append(a)
    prob_emo.append(combined_predict)    

dict_emo={0:'anger', 1:'disgust', 2:'fear', 3:'joy', 4:'sadness', 5:'surprise'}

for i in range(len(prob_emo)):
    index=np.argmax(prob_emo[i])
    predict.append(dict_emo[index])
######

dict2={'labels':data['labels'], 'text':data['text'], 'prob_emotion':prob_emo ,'emotion':predict} 
df=pd.DataFrame(dict2)
df.to_csv('TEC_nli_syn_avg_combined_probs.csv', index=False)

# %%
from sklearn.metrics import classification_report
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

data3=pd.read_csv('TEC_nli_syn_avg_combined_probs.csv')

label=data3['labels']
emotion=data3['emotion']
print(classification_report(label, emotion))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.25      0.53      0.34      1555
#      disgust       0.17      0.35      0.22       761
#         fear       0.51      0.33      0.40      2816
#          joy       0.67      0.41      0.51      8240
#      sadness       0.60      0.28      0.38      3830
#     surprise       0.29      0.58      0.39      3849
#
#     accuracy                           0.41     21051
#    macro avg       0.42      0.41      0.37     21051
# weighted avg       0.52      0.41      0.42     21051

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
data=pd.read_csv('TEC_nli_syn_avg_emotion_prompt2.csv')
data2=pd.read_csv('TEC_nli_syn_avg_two_syn_new.csv')
data3=pd.read_csv('TEC_nli_syn_avg_expr_prompt.csv')

#Isear_nli_syn_avg_emo_s_prompt2.csv
#Isear_nli_syn_avg_expr_s.csv

prob_emotion=data['prob_emotion']
prob_expr_s=data2['prob_emotion']
prob_expr_s3=data3['prob_expr_s']

prob_emotion2=list()
prob_expr_s2=list()
prob_expr_s32=list()

for m in prob_emotion:
    m = m.strip("[]")    
    string_elements = m.split(",")
    float_list = [float(element) for element in string_elements]
    prob_emotion2.append(float_list)

for m in prob_expr_s:
    m = m.strip("[]")    
    string_elements = m.split(",")
    float_list = [float(element) for element in string_elements]
    prob_expr_s2.append(float_list)

for m in prob_expr_s3:
    m = m.strip("[]")    
    string_elements = m.split(",")
    float_list = [float(element) for element in string_elements]
    prob_expr_s32.append(float_list)

predict=list()
prob_emo=list()

for i in range(len(prob_emotion2)):
    combined_predict=list()
    for j in range(len(prob_emotion2[0])):
        a=(prob_emotion2[i][j]+prob_expr_s2[i][j]+prob_expr_s32[i][j])/3
        combined_predict.append(a)
    prob_emo.append(combined_predict)    

dict_emo={0:'anger', 1:'disgust', 2:'fear', 3:'joy', 4:'sadness', 5:'surprise'}

for i in range(len(prob_emo)):
    index=np.argmax(prob_emo[i])
    predict.append(dict_emo[index])
######

dict2={'labels':data['labels'], 'text':data['text'], 'prob_emotion':prob_emo ,'emotion':predict} 
df=pd.DataFrame(dict2)
df.to_csv('TEC_nli_syn_avg_combined_probs2.csv', index=False)

# %%
from sklearn.metrics import classification_report
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

data3=pd.read_csv('TEC_nli_syn_avg_combined_probs2.csv')

label=data3['labels']
emotion=data3['emotion']
print(classification_report(label, emotion))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.27      0.53      0.35      1555
#      disgust       0.16      0.33      0.22       761
#         fear       0.47      0.32      0.38      2816
#          joy       0.67      0.42      0.51      8240
#      sadness       0.60      0.29      0.39      3830
#     surprise       0.28      0.55      0.37      3849
#
#     accuracy                           0.41     21051
#    macro avg       0.41      0.41      0.37     21051
# weighted avg       0.51      0.41      0.43     21051

# %%
from sklearn.metrics import classification_report
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

#'TEC_nli_syn_avg_two_syn_new.csv'
#'TEC_nli_syn_avg_emotion_prompt2.csv'
data3=pd.read_csv('TEC_nli_syn_avg_two_syn_new.csv')

label=data3['labels']
emotion=data3['emotion']
print(classification_report(label, emotion))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.19      0.54      0.28      1555
#      disgust       0.19      0.33      0.24       761
#         fear       0.61      0.30      0.40      2816
#          joy       0.68      0.39      0.50      8240
#      sadness       0.59      0.26      0.36      3830
#     surprise       0.30      0.57      0.39      3849
#
#     accuracy                           0.40     21051
#    macro avg       0.43      0.40      0.36     21051
# weighted avg       0.53      0.40      0.42     21051

# %%
#TEC_nli_syn_remove_syn4_new.csv
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
data=pd.read_csv('TEC_nli_syn_avg_emotion_prompt2.csv')
data2=pd.read_csv('TEC_nli_syn_emotion_prompt.csv')
#TEC_nli_syn_max_emo_s_prompt.csv
#TEC_nli_syn_emotion_prompt.csv

#Isear_nli_syn_avg_emo_s_prompt2.csv
#Isear_nli_syn_avg_expr_s.csv
#Isear_nli_syn_emotion_prompt_max_new2.csv
#TEC_nli_syn_emotion_prompt.csv
#TEC_nli_syn_remove_syn4_new.csv

prob_emotion=data['prob_emotion']

prob_expr_s=data2['prob_emotion']



prob_emotion2=list()
prob_expr_s2=list()

for m in prob_emotion:
    m = m.strip("[]")    
    string_elements = m.split(",")
    float_list = [float(element) for element in string_elements]
    prob_emotion2.append(float_list)

for m in prob_expr_s:
    m = m.strip("[]")    
    string_elements = m.split(",")
    float_list = [float(element) for element in string_elements]
    prob_expr_s2.append(float_list)


predict=list()
prob_emo=list()

for i in range(len(prob_emotion2)):
    combined_predict=list()
    for j in range(len(prob_emotion2[0])):
        a=(prob_emotion2[i][j]+prob_expr_s2[i][j])/2
        combined_predict.append(a)
    prob_emo.append(combined_predict)    

dict_emo={0:'anger', 1:'disgust', 2:'fear', 3:'joy', 4:'sadness', 5:'surprise'}

for i in range(len(prob_emo)):
    index=np.argmax(prob_emo[i])
    predict.append(dict_emo[index])
######

dict2={'labels':data['labels'], 'text':data['text'], 'prob_emotion':prob_emo ,'emotion':predict} 
df=pd.DataFrame(dict2)
df.to_csv('TEC_nli_syn_avg_combined_probs2.csv', index=False)

# %%
from sklearn.metrics import classification_report
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

#TEC_nli_syn_avg_combined_probs2.csv
#TEC_nli_syn_avg_combined_probs2.csv
#TEC_nli_syn_avg_emotion_prompt2
data3=pd.read_csv('TEC_nli_syn_avg_combined_probs2.csv')

label=data3['labels']
emotion=data3['emotion']
print(classification_report(label, emotion))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.26      0.51      0.35      1555
#      disgust       0.17      0.35      0.23       761
#         fear       0.49      0.32      0.39      2816
#          joy       0.67      0.40      0.50      8240
#      sadness       0.60      0.28      0.38      3830
#     surprise       0.28      0.58      0.38      3849
#
#     accuracy                           0.41     21051
#    macro avg       0.41      0.41      0.37     21051
# weighted avg       0.52      0.41      0.42     21051

# %%
from sklearn.metrics import classification_report
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

#TEC_nli_syn_avg_combined_probs2.csv
#TEC_nli_syn_avg_combined_probs2.csv
#TEC_nli_syn_avg_emotion_prompt2
data3=pd.read_csv('TEC_nli_syn_avg_emotion_prompt2.csv')

label=data3['labels']
emotion=data3['emotion']
print(classification_report(label, emotion))

# %%
from sklearn.metrics import classification_report
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

#TEC_nli_syn_avg_combined_probs2.csv
#TEC_nli_syn_avg_combined_probs2.csv
#TEC_nli_syn_avg_emotion_prompt2
data3=pd.read_csv('TEC_nli_syn_avg_emotion_prompt2.csv')

label=data3['labels']
emotion=data3['emotion']
print(classification_report(label, emotion))
