# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#Isear_nli_syn_emotion_prompt_max_new_syn2.csv
data=pd.read_csv('TEC_nli_syn_max_emo_s_prompt.csv')

d= data['prob_emo_s']
e=data['emo_s']
d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()
surprise=list()


for i in range(len(label_list)):
    if label_list[i]=='anger' and e[i]=='anger':
        anger.append(d[i])
    if label_list[i]=='disgust' and e[i]=='disgust':
        disgust.append(d[i])
    if label_list[i]=='fear' and e[i]=='fear':
        fear.append(d[i])
    if label_list[i]=='joy' and e[i]=='joy':
        joy.append(d[i])
    if label_list[i]=='sadness' and e[i]=='sadness':
        sadness.append(d[i])
    if label_list[i]=='surprise' and e[i]=='surprise':
        surprise.append(d[i])
                    
#m=np.sum(anger, axis=0)/len(anger)
#m=np.average(anger, axis=0)
#an=[sum(x)/len(x) for x in zip(*anger)]

avg_syn_anger=list()
#anger 6


for i in range(6):
    s=0
    for m in surprise:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        
#        print(float_list)
#        print("#")
        if float_list[i]: 
            s+=float_list[i]
    avg_syn_anger.append(s/len(surprise))
        
        
print(avg_syn_anger)

#anger [0.865315881962106, 0.6973527183063961, 0.49801810188592194, 0.2101213320783599, 0.6504759164420418, 0.6532974270934893]
#anger
#disgust [0.710484701669169, 0.8915525221801682, 0.5326841130670102, 0.12038000973024444, 0.5998738563493571, 0.6576146293945822]
#loathing
#fear [0.46349439227738604, 0.5990350513061343, 0.8176751835022948, 0.24317873995467393, 0.4468821131880628, 0.6320463855733756]
#anxiety
#joy [0.20935972547335402, 0.2509788273081628, 0.1514506175692631, 0.7927521206688448, 0.11015297358795217, 0.6329543008698065]
#the blessing
#sadness [0.5154925453301267, 0.5410572514848193, 0.47541009101800746, 0.14905995438524539, 0.8209210455399907, 0.6278919553774751]
#'depression'
#surprise [0.3725799971872547, 0.36821910063057617, 0.3209568099953862, 0.41221270556015893, 0.27255148484925984, 0.7563424516187692]
#'shock'
# Out:
# [0.3725799971872547, 0.36821910063057617, 0.3209568099953862, 0.41221270556015893, 0.27255148484925984, 0.7563424516187692]

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#Isear_nli_syn_emotion_prompt_max_new_syn2.csv
data=pd.read_csv('TEC_nli_syn_max_emo_s_prompt.csv')

d= data['prob_emo_s']
e=data['emo_s']
d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()
surprise=list()


for i in range(len(label_list)):
    if label_list[i]=='anger' and e[i]!='anger':
        anger.append(d[i])
    if label_list[i]=='disgust' and e[i]!='disgust':
        disgust.append(d[i])
    if label_list[i]=='fear' and e[i]!='fear':
        fear.append(d[i])
    if label_list[i]=='joy' and e[i]!='joy':
        joy.append(d[i])
    if label_list[i]=='sadness' and e[i]!='sadness':
        sadness.append(d[i])
    if label_list[i]=='surprise' and e[i]!='surprise':
        surprise.append(d[i])
                    
#m=np.sum(anger, axis=0)/len(anger)
#m=np.average(anger, axis=0)
#an=[sum(x)/len(x) for x in zip(*anger)]

avg_syn_anger=list()
#anger 6


for i in range(6):
    s=0
    for m in sadness:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        
#        print(float_list)
#        print("#")
        if float_list[i]: 
            s+=float_list[i]
    avg_syn_anger.append(s/len(sadness))
        
        
print(avg_syn_anger)

#anger [0.6192468892601473, 0.6034888742054283, 0.4696874571758357, 0.22507349295600584, 0.5480847117421285, 0.6734789615168072]
#disgust [0.5606022425633244, 0.5399851009315538, 0.39636113213356394, 0.22438094728428465, 0.46494360531226386, 0.7214563255647498]
#fear [0.41320741031573105, 0.4881373732787652, 0.39796057588997474, 0.3510315417822538, 0.33226600069297774, 0.652709530447844]
#joy [0.46303549280927087, 0.44534005245779584, 0.3794103074992846, 0.30496520505101954, 0.39220411087767576, 0.6344952877593987]
#sadness [0.5208892543711825, 0.49201408627173077, 0.4101224437499396, 0.24678050938893203, 0.49273849981613144, 0.6779480198852162]
#surprise [0.4001940002446482, 0.4527247401570431, 0.30412680381856133, 0.5269131179924913, 0.3002616742733218, 0.6085586403761991]
# Out:
# [0.5208892543711825, 0.49201408627173077, 0.4101224437499396, 0.24678050938893203, 0.49273849981613144, 0.6779480198852162]
