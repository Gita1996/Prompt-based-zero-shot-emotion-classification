# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#Isear_nli_syn_emotion_prompt_max_new_syn2.csv
data=pd.read_csv('Isear_nli_syn_emotion_prompt_max_new_syn2.csv')

d= data['probs_synonyms']
e=data['emotion']
d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()


for i in range(len(label_list)):
    if label_list[i]=='anger' and e[i]=='anger':
        anger.append(d[i])
    if label_list[i]=='disgust' and e[i]=='disgust':
        disgust.append(d[i])
    if label_list[i]=='fear' and e[i]=='fear':
        fear.append(d[i])
    if label_list[i]=='guilt' and e[i]=='guilt':
        guilt.append(d[i])
    if label_list[i]=='joy' and e[i]=='joy':
        joy.append(d[i])
    if label_list[i]=='sadness' and e[i]=='sadness':
        sadness.append(d[i])
    if label_list[i]=='shame' and e[i]=='shame':
        shame.append(d[i])
                    
#m=np.sum(anger, axis=0)/len(anger)
#m=np.average(anger, axis=0)
#an=[sum(x)/len(x) for x in zip(*anger)]

avg_syn_anger=list()
#anger 6


for i in range(6):
    s=0
    for m in guilt:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        
#        print(float_list)
#        print("#")
        if float_list[i]: 
            s+=float_list[i]
    avg_syn_anger.append(s/len(guilt))
        
        
print(avg_syn_anger)

#anger [0.9564253988964805, 0.7719387822045848, 0.8444076497835674, 0.8847650636201617, 0.8496336282498536, 0.9534665096080166]
#anger
#disgust [0.9291027251608167, 0.8526225928498093, 0.7355170835034278, 0.8212644144367038, 0.9478798231189968, 0.9158956769154862]
#repugnance
#fear [0.9341381691272747, 0.7833563738296745, 0.9076191444135173, 0.8522073593340526, 0.8671326128282271, 0.9480084148395127]
#scare
#guilt [0.9384460117622719, 0.9523845883651251, 0.9078211666212338, 0.7869143707603474, 0.8342188238012935, 0.8775858980711659]
#culpability
#joy [0.8730578005301874, 0.7460287497263509, 0.8958230977038031, 0.7832523599955575, 0.9130251163448788, 0.7047674157781336]
#happiness
#sadness [0.8730578005301874, 0.7460287497263509, 0.8958230977038031, 0.7832523599955575, 0.9130251163448788, 0.7047674157781336]
#loneliness
#shame [0.8836583654134241, 0.9223789350269267, 0.926798774629403, 0.8575127110386256, 0.8727789056282759, 0.8496243883788708]
#embarrassment
# Out:
# [0.9384460117622719, 0.9523845883651251, 0.9078211666212338, 0.7869143707603474, 0.8342188238012935, 0.8775858980711659]

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#Isear_nli_syn_emotion_prompt_max_new_syn2.csv
data=pd.read_csv('Isear_nli_syn_emotion_prompt_max_new_syn2.csv')

d= data['probs_synonyms']
e=data['emotion']
d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()


for i in range(len(label_list)):
    if label_list[i]=='anger' and e[i] !='anger':
        anger.append(d[i])
    if label_list[i]=='disgust' and e[i]!='disgust':
        disgust.append(d[i])
    if label_list[i]=='fear' and e[i] !='fear':
        fear.append(d[i])
    if label_list[i]=='guilt' and e[i]!='guilt':
        guilt.append(d[i])
    if label_list[i]=='joy' and e[i] !='joy':
        joy.append(d[i])
    if label_list[i]=='sadness' and e[i]!='sadness':
        sadness.append(d[i])
    if label_list[i]=='shame' and e[i] !='shame':
        shame.append(d[i])
                    
#m=np.sum(anger, axis=0)/len(anger)
#m=np.average(anger, axis=0)
#an=[sum(x)/len(x) for x in zip(*anger)]

avg_syn_anger=list()
#anger 6


for i in range(6):
    s=0
    for m in shame:
        m = m.strip("[]")    
        string_elements = m.split(",")
        float_list = [float(element) for element in string_elements]
        
#        print(float_list)
#        print("#")
        if float_list[i]: 
            s+=float_list[i]
    avg_syn_anger.append(s/len(shame))
        
        
print(avg_syn_anger)

#anger [0.7532500699804213, 0.8557420707440079, 0.5595895645513433, 0.7296766726705405, 0.6027575805339483, 0.8850416908360965]
#disgust [0.7532500699804213, 0.8557420707440079, 0.5595895645513433, 0.7296766726705405, 0.6027575805339483, 0.8850416908360965]
#fear [0.7184490936410706, 0.6760711011739601, 0.7266285226418915, 0.6046209041633758, 0.674449044968715, 0.7790925779614096]
#guilt [0.7184490936410706, 0.6760711011739601, 0.7266285226418915, 0.6046209041633758, 0.674449044968715, 0.7790925779614096]
#joy [0.3630839538226095, 0.40683420621846095, 0.40144296725426454, 0.44164716749149097, 0.4535665238431812, 0.286346538867577]
#sadness [0.6182542250395355, 0.7369473352475768, 0.4878453714241212, 0.5631470773061785, 0.34231865833581987, 0.3663647783548467]
#shame [0.6736357706495878, 0.699007685833562, 0.7196724798619246, 0.6252013093953169, 0.7210268000147165, 0.6953760458763262]
# Out:
# [0.6736357706495878, 0.699007685833562, 0.7196724798619246, 0.6252013093953169, 0.7210268000147165, 0.6953760458763262]

# %%
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report


#Isear_nli_syn_avg_emotion_prompt2_syn_probs.csv
#Isear_nli_syn_emotion_prompt_max_new_syn2.csv
data=pd.read_csv('Isear_nli_syn_emotion_prompt_max_new_syn2.csv')

d= data['probs_synonyms']
e=data['emotion']
d2=d.tolist()
#print(d[0])

label_list = data['labels'].tolist()
emotion_word=data['emotion_word'].tolist()
anger=list()
disgust=list()
fear=list()
guilt=list()
joy=list()
sadness=list()
shame=list()

#anger
anger=0
annoyance=0
rage=0
outrage=0
fury=0
irritation=0

for i in range(len(label_list)):
    if label_list[i]=='anger' and e[i]=='anger':
        if emotion_word[i]=='anger':
            anger+=1
        if emotion_word[i]=='annoyance':
            annoyance+=1
        if emotion_word[i]=='rage':
            rage+=1
        if emotion_word[i]=='outrage':
            outrage+=1
        if emotion_word[i]=='fury':
            fury+=1
        
    if label_list[i]=='disgust' and e[i]=='disgust':
        disgust.append(d[i])
    if label_list[i]=='fear' and e[i]=='fear':
        fear.append(d[i])
    if label_list[i]=='guilt' and e[i]=='guilt':
        guilt.append(d[i])
    if label_list[i]=='joy' and e[i]=='joy':
        joy.append(d[i])
    if label_list[i]=='sadness' and e[i]=='sadness':
        sadness.append(d[i])
    if label_list[i]=='shame' and e[i]=='shame':
        shame.append(d[i])

# %%
from sklearn.metrics import classification_report
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

#TEC_nli_syn_avg_combined_probs2.csv
#TEC_nli_syn_avg_combined_probs2.csv
#TEC_nli_syn_avg_emotion_prompt2
#Isear_nli_syn_max_emotion_prompt.csv
#Isear_nli_syn_avg_combined_probs2.csv
data3=pd.read_csv('Isear_nli_syn_avg_combined_probs2.csv')

label=data3['labels']
emotion=data3['emotion']
print(classification_report(label, emotion))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.56      0.46      0.50      1079
#      disgust       0.78      0.44      0.56      1066
#         fear       0.64      0.83      0.72      1076
#        guilt       0.53      0.64      0.58      1049
#          joy       0.86      0.93      0.89      1092
#      sadness       0.69      0.76      0.72      1082
#        shame       0.54      0.50      0.52      1071
#
#     accuracy                           0.65      7515
#    macro avg       0.66      0.65      0.64      7515
# weighted avg       0.66      0.65      0.64      7515
