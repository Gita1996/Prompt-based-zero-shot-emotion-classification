# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC expr-emo3-Deberta.csv')
y_true = data['labels'].tolist()
y_pred = data['expr_emo'].tolist()

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.30      0.37      0.33      1555
#      disgust       0.15      0.45      0.23       761
#         fear       0.50      0.32      0.39      2816
#          joy       0.68      0.36      0.47      8240
#      sadness       0.51      0.38      0.43      3830
#     surprise       0.29      0.58      0.38      3849
#
#     accuracy                           0.40     21051
#    macro avg       0.40      0.41      0.37     21051
# weighted avg       0.51      0.40      0.42     21051

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC2_roberta_expr_nli2.csv')
y_true = data['labels'].tolist()
y_pred = data['expr_emo'].tolist()

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.25      0.40      0.31      1555
#      disgust       0.18      0.31      0.23       761
#         fear       0.35      0.25      0.29      2816
#          joy       0.69      0.33      0.45      8240
#      sadness       0.36      0.39      0.38      3830
#     surprise       0.29      0.54      0.38      3849
#
#     accuracy                           0.37     21051
#    macro avg       0.35      0.37      0.34     21051
# weighted avg       0.46      0.37      0.38     21051

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC expr-emo3-Deberta.csv')
y_true = data['labels'].tolist()
y_pred = data['expr_emo'].tolist()

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.30      0.37      0.33      1555
#      disgust       0.15      0.45      0.23       761
#         fear       0.50      0.32      0.39      2816
#          joy       0.68      0.36      0.47      8240
#      sadness       0.51      0.38      0.43      3830
#     surprise       0.29      0.58      0.38      3849
#
#     accuracy                           0.40     21051
#    macro avg       0.40      0.41      0.37     21051
# weighted avg       0.51      0.40      0.42     21051

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('TEC expr-emo3-Deberta.csv')
y_true = data['labels'].tolist()
y_pred = data['expr_emo'].tolist()

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.30      0.37      0.33      1555
#      disgust       0.15      0.45      0.23       761
#         fear       0.50      0.32      0.39      2816
#          joy       0.68      0.36      0.47      8240
#      sadness       0.51      0.38      0.43      3830
#     surprise       0.29      0.58      0.38      3849
#
#     accuracy                           0.40     21051
#    macro avg       0.40      0.41      0.37     21051
# weighted avg       0.51      0.40      0.42     21051

# %%
import argparse
import statistics
import numpy as np
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sklearn.metrics import classification_report

#data = pd.read_csv('ISEAR-nli-prompt-emotion3-deberta.csv')
#ISEAR-nli-prompt-emotion-roberta.csv
data = pd.read_csv('Tec_bart_expr_emo3.csv')
y_true = data['labels'].tolist()
y_pred = data['expr_emo'].tolist()

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.23      0.44      0.30      1555
#      disgust       0.17      0.53      0.26       761
#         fear       0.45      0.27      0.34      2816
#          joy       0.64      0.41      0.50      8240
#      sadness       0.47      0.39      0.43      3830
#     surprise       0.30      0.43      0.35      3849
#
#     accuracy                           0.40     21051
#    macro avg       0.38      0.41      0.36     21051
# weighted avg       0.47      0.40      0.42     21051
