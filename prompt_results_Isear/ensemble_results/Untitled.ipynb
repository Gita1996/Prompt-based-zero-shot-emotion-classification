# %%
from sklearn.metrics import classification_report
import argparse
import statistics
import pandas as pd
import numpy as np

import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

data3=pd.read_csv('ensemble_result_isear-roberta.csv')

label=data3['labels']
emotion=data3['ensemble']
print(classification_report(label, emotion))

#ensemble_result_isear.Deberta.csv  #accuracy:0.61  Macro avg f1:0.59
# ensemble_result_isear-Bart.csv         #accuracy: 0.61  Macro avg f1: 0.61
#ensemble_result_isear-roberta.csv        #accuracy: 0.52  macro avg:0.52
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.48      0.45      0.47      1079
#      disgust       0.73      0.37      0.50      1066
#         fear       0.79      0.49      0.60      1076
#        guilt       0.31      0.58      0.41      1049
#          joy       0.93      0.64      0.76      1092
#      sadness       0.43      0.81      0.56      1082
#        shame       0.57      0.28      0.38      1071
#
#     accuracy                           0.52      7515
#    macro avg       0.61      0.52      0.52      7515
# weighted avg       0.61      0.52      0.53      7515
